# %% [markdown]
# # Import Librarys

# %%
import pandas as pd
import numpy as np 
import requests
import json

# %% [markdown]
# # Setup Tasty Api requirements

# %%
key = open('Keys/Key_Tasty.txt','r').read()
host = 'tasty.p.rapidapi.com'
headers = {'x-rapidapi-host':host,'x-rapidapi-key':key}

# %% [markdown]
# ## Request a list of all recepies tags

# %%
url = "https://tasty.p.rapidapi.com/tags/list" 
response = requests.request("GET", url, headers=headers)
tag=json.loads(response.text)

# %% [markdown]
# ### Create a Set with all tag Names

# %%
tags_name = set([tag['results'][i]['name'] for i in range(len(tag['results']))])
tags_name
# Out:
# {'3_musketeers',
#  '5_ingredients_or_less',
#  'african',
#  'air_fryer',
#  'almond_joy',
#  'american',
#  'appetizers',
#  'asian_pacific_american_heritage_month',
#  'bake',
#  'bakery_goods',
#  'baking_cups',
#  'baking_kit',
#  'baking_pan',
#  'bbq',
#  'best_of_tasty',
#  'beyond_red_blend',
#  'big_batch',
#  'black_history_month',
#  'blender',
#  'brazilian',
#  'bread_pan',
#  'breakfast',
#  'british',
#  'broiler',
#  'brunch',
#  'budget_10',
#  'budget_expert',
#  'budget_four',
#  'budget_plans',
#  'budget_shop',
#  'butterfinger_other_recipes',
#  'butterfinger_runner_up_bark',
#  'butterfinger_runner_up_cookies',
#  'butterfinger_winner',
#  'cake_pan',
#  'caribbean',
#  'cast_iron_pan',
#  'casual_party',
#  'cheese_grater',
#  'chefs_knife',
#  'chinese',
#  'chop_champ',
#  'christmas',
#  'cinco_de_mayo',
#  'club_house_seasoned_pro',
#  'colander',
#  'comfort_food',
#  'contains_alcohol',
#  'cooking_kit',
#  'cooling_rack',
#  'cuban',
#  'cupcake_pan',
#  'cutting_board',
#  'dairy_free',
#  'date_night',
#  'deep_fry',
#  'deeply_blood_orange',
#  'desserts',
#  'dinner',
#  'dominican',
#  'drinks',
#  'dry_measuring_cups',
#  'dutch_oven',
#  'easter',
#  'easy',
#  'eko_video',
#  'epoca_walmart',
#  'ethiopian',
#  'every_occasion',
#  'fall',
#  'filipino',
#  'fish_spatula',
#  'food_processor',
#  'for_real_grapefruit',
#  'fourth_desserts',
#  'fourth_drink',
#  'fourth_eat',
#  'fourth_of_july',
#  'fourth_picks',
#  'fourth_sides',
#  'frank_s_cheesy_apps',
#  'frank_s_chicken_bites',
#  'frank_s_vegetarian_snacks',
#  'franks_dips',
#  'franks_handheld_bites',
#  'franks_nachos',
#  'franks_spicy_bites',
#  'freezer',
#  'french',
#  'fusion',
#  'game_day',
#  'german',
#  'gluten_free',
#  'greek',
#  'grill',
#  'haitian',
#  'halloween',
#  'hand_mixer',
#  'happy_hour',
#  'hawaiian',
#  'healthy',
#  'hershey_s',
#  'holiday_cookie_hacks',
#  'holiday_cookie_howto',
#  'holiday_cookie_recipe',
#  'holiday_treats',
#  'ice_cream_scoop',
#  'ice_cream_social',
#  'ice_cube_tray',
#  'indian',
#  'indigenous',
#  'indulgent_sweets',
#  'instant_pot',
#  'italian',
#  'jamaican',
#  'japanese',
#  'kenyan',
#  'kid_friendly',
#  'kitchen_shears',
#  'korean',
#  'laotian',
#  'latin_american',
#  'latinx_heritage_month',
#  'lebanese',
#  'licensed_video',
#  'light_bites',
#  'lil_brut',
#  'liquid_measuring_cup',
#  'live_jasmine_and_tucker',
#  'live_past_lives',
#  'live_shop_all',
#  'live_upcoming',
#  'lollipop_sticks',
#  'low_carb',
#  'lunar_new_year',
#  'lunch',
#  'mashup',
#  'mc_breakfast_easy',
#  'mc_breakfast_healthy',
#  'mc_breakfast_savory',
#  'mc_breakfast_sweet',
#  'mccormick_easy_dinner',
#  'mccormick_game_day',
#  'mccormick_seasoned_pro',
#  'mccormick_ugc_one_pot_others',
#  'mccormick_ugc_one_pot_pasta',
#  'mccormick_ugc_one_pot_slow',
#  'mccormick_ugc_one_pot_winners',
#  'meal_prep',
#  'measuring_spoons',
#  'mexican',
#  'microplane',
#  'microwave',
#  'middle_eastern',
#  'mixing_bowl',
#  'mothers_day',
#  'no_bake_desserts',
#  'nynm_desserts',
#  'nynm_expert',
#  'nynm_instant_pot',
#  'nynm_meal_prep',
#  'nynm_money',
#  'nynm_protein',
#  'nynm_veggie',
#  'offset_spatula',
#  'oh_so_rose',
#  'one_pot_or_pan',
#  'one_top_app_dessert',
#  'one_top_app_eggs',
#  'one_top_app_grains',
#  'one_top_app_main_feed',
#  'one_top_app_meat',
#  'one_top_app_sauces',
#  'one_top_app_seafood',
#  'one_top_app_sides',
#  'one_top_app_steak',
#  'one_top_app_veggies',
#  'one_top_friendly',
#  'oven',
#  'oven_mitts',
#  'pan_fry',
#  'paper_bowls',
#  'paper_cups',
#  'paper_napkins',
#  'paper_plates',
#  'parchment_paper',
#  'passover',
#  'peeler',
#  'peppermint_pattie',
#  'perf_pinot_noir',
#  'persian',
#  'peruvian',
#  'pescatarian',
#  'pie_dish',
#  'plastic_utensils',
#  'plastic_wrap',
#  'pressure_cooker',
#  'pride_month',
#  'puerto_rican',
#  'pyrex',
#  'qfp_baking',
#  'qfp_recipes',
#  'raspberry_rose',
#  'rolling_pin',
#  'sauce_pan',
#  'saute_pan',
#  'schwartz_seasoned_pro',
#  'seafood',
#  'shoppable_recipes_desserts',
#  'shoppable_recipes_family_dinner',
#  'shoppable_recipes_holiday_appetizers',
#  'shoppable_recipes_holiday_dinners',
#  'shoppable_recipes_meal_prep',
#  'shoppable_recipes_seasonal_desserts',
#  'shoppable_recipes_thanksgiving',
#  'sides',
#  'sieve',
#  'slow_cooker',
#  'snacks',
#  'snickers',
#  'soul_food',
#  'south_african',
#  'sparkling_rose',
#  'spatula',
#  'special_occasion',
#  'spider',
#  'sponsored_recipe',
#  'spring',
#  'spring_drink',
#  'spring_eat',
#  'spring_holiday',
#  'spring_kitchen',
#  'spring_sides',
#  'srsly_sauv_blanc',
#  'st_patrick_s_day',
#  'steam',
#  'stove_top',
#  'strainer',
#  'stuffed',
#  'summer',
#  'summer_desserts',
#  'summer_drink',
#  'summer_eat',
#  'summer_holiday',
#  'summer_sides',
#  'swedish',
#  'taiwanese',
#  'tasty_cookbook',
#  'tasty_dinner_kits',
#  'tasty_ewd_comfort',
#  'tasty_ewd_fall',
#  'tasty_ewd_family',
#  'tasty_ewd_fifteen',
#  'tasty_ewd_healthy',
#  'tasty_ewd_tips',
#  'tasty_holiday_christmas',
#  'tasty_holiday_festive_favorites',
#  'tasty_holiday_hanukkah',
#  'tasty_holiday_nye',
#  'tasty_holiday_snacks',
#  'tasty_holiday_thanksgiving',
#  'tasty_junior_cookbook',
#  'tasty_s_5th_birthday_recipe',
#  'tasty_s_5th_birthday_savory',
#  'tasty_s_5th_birthday_sweet',
#  'tastyjunior',
#  'thai',
#  'thanksgiving',
#  'thanksgiving_classics',
#  'thanksgiving_desserts',
#  'thanksgiving_sides',
#  'thanksgiving_sips',
#  'thanksgiving_slow',
#  'thanksgiving_vegetarian',
#  'tips_basics',
#  'tips_culinary',
#  'tips_pros',
#  'tips_viral',
#  'tongs',
#  'tupperware',
#  'uber_game_day_appetizers',
#  'uber_game_day_dips',
#  'uber_game_day_ribs',
#  'uber_game_day_sliders',
#  'under_30_minutes',
#  'valentines_day',
#  'vegan',
#  'vegetarian',
#  'venezuelan',
#  'vietnamese',
#  'walmart_holiday_bundle',
#  'walmart_plus_holiday_2020',
#  'wax_paper',
#  'weeknight',
#  'west_african',
#  'whisk',
#  'winter',
#  'wok',
#  'wooden_spoon',
#  'zipper_freezer_bags',
#  'zipper_storage_bags'}

# %% [markdown]
# ### Request all recipes per tag

# %%
for tag in tags_name :
    url = "https://tasty.p.rapidapi.com/recipes/list"
    querystring = {"from":"0","size":"100","tags":tag}
    response = requests.request("GET", url, headers=headers, params=querystring)
    recipes=json.loads(response.text)

# %% [markdown]
# ### Understand response data from API

# %%
url = "https://tasty.p.rapidapi.com/recipes/list"
querystring = {"from":"0","size":"100","tags":"easy"}
response = requests.request("GET", url, headers=headers, params=querystring)
recipes=json.loads(response.text)

# %%
recipes

# %%
len(recipes['results'])

# %%
recipes['results'][8].keys()

# %%
recipes['results'][8]['tags'][0]['name']

# %%
recipes['results'][36].keys()

# %%
recipes['results'][36]['original_video_url']

# %% [markdown]
# ## Request all recipes per tag, and  create a DataFrame with all recipes

# %%
recipe_id=[]
recipe_name=[]
recipe_score=[]
recipe_positivevotes=[]
recipe_negativevotes=[]
recipe_totalvotes=[]
recipe_country=[]
recipe_servings=[]
recipe_instructions=[]
recipe_totalingredients=[]
ingredient_text=[]
ingredient_id=[]
ingredient_name=[]
ingredient_quantity=[]
unit_id=[]
unit_name=[]
Recipe_calories=[]
Recipe_carbohydrates=[]
Recipe_protein=[]
Recipe_fat=[]
Recipe_fiber=[]
Recipe_sugar=[]
Recipe_video=[]
Recipe_tags=[]
for tag in tags_name :
    url = "https://tasty.p.rapidapi.com/recipes/list"
    querystring = {"from":"0","size":"100","tags":tag}
    response = requests.request("GET", url, headers=headers, params=querystring)
    recipes=json.loads(response.text)
    if len(recipes['results']) > 0 :
        for i in range(len(recipes['results'])) :
            if 'recipes' not in recipes['results'][i].keys() :
                recipeid = recipes['results'][i]['id']
                recipename = recipes['results'][i]['name']
                recipescore = recipes['results'][i]['user_ratings']['score']
                recipepositivevotes = recipes['results'][i]['user_ratings']['count_positive']
                recipenegativevotes = recipes['results'][i]['user_ratings']['count_negative']
                recipetotalvotes = recipes['results'][i]['user_ratings']['count_positive'] + recipes['results'][i]['user_ratings']['count_negative']
                recipecountry = recipes['results'][i]['country']
                recipeservings = recipes['results'][i]['num_servings']
                recipevideo = recipes['results'][i]['original_video_url']
                recipetag=[tag['name'] for tag in recipes['results'][i]['tags']]
                recipeinstructions= ' '.join([instruction['display_text'] for instruction in recipes['results'][i]['instructions']])
                recipetotalingredients = len(recipes['results'][i]['sections'][0]['components'])
                for j in range(len(recipes['results'][i]['sections'][0]['components'])) :
                    ingredienttext = recipes['results'][i]['sections'][0]['components'][j]['raw_text']
                    ingredientid = recipes['results'][i]['sections'][0]['components'][j]['ingredient']['id']
                    ingredientname = recipes['results'][i]['sections'][0]['components'][j]['ingredient']['name']
                    try :                   
                        ingredientquantity = recipes['results'][i]['sections'][0]['components'][j]['measurements'][0]['quantity']
                        unitid = recipes['results'][i]['sections'][0]['components'][j]['measurements'][0]['id']
                        unitname = recipes['results'][i]['sections'][0]['components'][j]['measurements'][0]['unit']['name']
                    except IndexError :
                        ingredientquantity = None
                        unitid = None
                        unitname = None
                    if bool(recipes['results'][i]['nutrition']):
                        calories = recipes['results'][i]['nutrition']['calories'] 
                        carbohydrates = recipes['results'][i]['nutrition']['carbohydrates'] 
                        protein = recipes['results'][i]['nutrition']['protein'] 
                        fat = recipes['results'][i]['nutrition']['fat'] 
                        fiber = recipes['results'][i]['nutrition']['fiber'] 
                        sugar = recipes['results'][i]['nutrition']['sugar']
                    else :
                        calories = None 
                        carbohydrates = None 
                        protein = None 
                        fat = None 
                        fiber = None 
                        sugar = None
                    ingredient_text.append(ingredienttext)
                    ingredient_id.append(ingredientid)
                    ingredient_name.append(ingredientname)
                    ingredient_quantity.append(ingredientquantity)
                    unit_id.append(unitid)
                    unit_name.append(unitname)
                    Recipe_calories.append(calories)
                    Recipe_carbohydrates.append(carbohydrates)
                    Recipe_protein.append(protein)
                    Recipe_fat.append(fat)
                    Recipe_fiber.append(fiber)
                    Recipe_sugar.append(sugar)
                    recipe_id.append(recipeid)
                    recipe_name.append(recipename)
                    recipe_score.append(recipescore)
                    recipe_positivevotes.append(recipepositivevotes)
                    recipe_negativevotes.append(recipenegativevotes)
                    recipe_totalvotes.append(recipetotalvotes)
                    recipe_country.append(recipecountry)
                    recipe_servings.append(recipeservings)
                    recipe_instructions.append(recipeinstructions)
                    recipe_totalingredients.append(recipetotalingredients)
                    Recipe_video.append(recipevideo)
                    Recipe_tags.append(recipetag)
            else :
                for k in range(len(recipes['results'][i]['recipes'])) :
                    recipeid = recipes['results'][i]['recipes'][k]['id']
                    recipename = recipes['results'][i]['recipes'][k]['name']
                    recipescore = recipes['results'][i]['recipes'][k]['user_ratings']['score']
                    recipepositivevotes = recipes['results'][i]['recipes'][k]['user_ratings']['count_positive']
                    recipenegativevotes = recipes['results'][i]['recipes'][k]['user_ratings']['count_negative']
                    recipetotalvotes = recipes['results'][i]['recipes'][k]['user_ratings']['count_positive'] + recipes['results'][i]['recipes'][k]['user_ratings']['count_negative']
                    recipecountry = recipes['results'][i]['recipes'][k]['country']
                    recipeservings = recipes['results'][i]['recipes'][k]['num_servings']
                    recipevideo = recipes['results'][i]['recipes'][k]['original_video_url']
                    recipetag=[tag['name'] for tag in recipes['results'][i]['recipes'][k]['tags']]
                    recipeinstructions= ' '.join([instruction['display_text'] for instruction in recipes['results'][i]['recipes'][k]['instructions']])
                    recipetotalingredients = int(len(recipes['results'][i]['recipes'][k]['sections'][0]['components']))
                    for j in range(len(recipes['results'][i]['recipes'][k]['sections'][0]['components'])) :
                        ingredienttext = recipes['results'][i]['recipes'][k]['sections'][0]['components'][j]['raw_text']
                        ingredientid = recipes['results'][i]['recipes'][k]['sections'][0]['components'][j]['ingredient']['id']
                        ingredientname = recipes['results'][i]['recipes'][k]['sections'][0]['components'][j]['ingredient']['name']
                        try :
                            ingredientquantity = recipes['results'][i]['recipes'][k]['sections'][0]['components'][j]['measurements'][0]['quantity']
                            unitid = recipes['results'][i]['recipes'][k]['sections'][0]['components'][j]['measurements'][0]['id']
                            unitname = recipes['results'][i]['recipes'][k]['sections'][0]['components'][j]['measurements'][0]['unit']['name']
                        except IndexError :
                            ingredientquantity = None
                            unitid = None
                            unitname = None 
                        if bool(recipes['results'][i]['recipes'][k]['nutrition']) :
                            calories = recipes['results'][i]['recipes'][k]['nutrition']['calories'] 
                            carbohydrates = recipes['results'][i]['recipes'][k]['nutrition']['carbohydrates'] 
                            protein = recipes['results'][i]['recipes'][k]['nutrition']['protein'] 
                            fat = recipes['results'][i]['recipes'][k]['nutrition']['fat'] 
                            fiber = recipes['results'][i]['recipes'][k]['nutrition']['fiber'] 
                            sugar = recipes['results'][i]['recipes'][k]['nutrition']['sugar']
                        else :
                            calories = None 
                            carbohydrates = None 
                            protein = None 
                            fat = None 
                            fiber = None 
                            sugar = None
                        ingredient_text.append(ingredienttext)
                        ingredient_id.append(ingredientid)
                        ingredient_name.append(ingredientname)
                        ingredient_quantity.append(ingredientquantity)
                        unit_id.append(unitid)
                        unit_name.append(unitname)
                        Recipe_calories.append(calories)
                        Recipe_carbohydrates.append(carbohydrates)
                        Recipe_protein.append(protein)
                        Recipe_fat.append(fat)
                        Recipe_fiber.append(fiber)
                        Recipe_sugar.append(sugar)
                        recipe_id.append(recipeid)
                        recipe_name.append(recipename)
                        recipe_score.append(recipescore)
                        recipe_positivevotes.append(recipepositivevotes)
                        recipe_negativevotes.append(recipenegativevotes)
                        recipe_totalvotes.append(recipetotalvotes)
                        recipe_country.append(recipecountry)
                        recipe_servings.append(recipeservings)
                        recipe_instructions.append(recipeinstructions)
                        recipe_totalingredients.append(recipetotalingredients)
                        Recipe_video.append(recipevideo)
                        Recipe_tags.append(recipetag)
        df_recepies = pd.DataFrame({'Recipe_id':recipe_id,'Recipe_name':recipe_name,'Recipe_score':recipe_score,'Recipe_positivevotes':recipe_positivevotes,'Recipe_negativevotes':recipe_negativevotes,
                                    'Recipe_totalvotes':recipe_totalvotes,'Recipe_country':recipe_country,'Recipe_servings':recipe_servings,'Recipe_instructions':recipe_instructions,'Recipe_totalingredients':recipe_totalingredients,
                                    'Ingredient_text':ingredient_text,'Ingredient_id':ingredient_id,'Ingredient_name':ingredient_name,'Ingredient_quantity':ingredient_quantity,'Unit_id':unit_id,
                                    'Unit_name':unit_name,'Recipe_calories':Recipe_calories,'Recipe_carbohydrates':Recipe_carbohydrates,'Recipe_protein':Recipe_protein,'Recipe_fat':Recipe_fat,
                                    'Recipe_fiber':Recipe_fiber,'Recipe_sugar':Recipe_sugar,'Recipe_video':Recipe_video,'Recipe_tags':Recipe_tags})

# %%
df_recepies.info()

# %% [markdown]
# ### Save DataFrame as CSV File

# %%
df_recepies.to_csv('Tasty.csv')

# %%
df_recepies = pd.read_csv('Tasty.csv')

# %%
df_recepies = df_recepies.drop('Unnamed: 0',axis=1)
df_recepies
# Out:
#        Recipe_id                 Recipe_name  Recipe_score  \
# 0           8064    Butterfinger Toffee Bark      1.000000
# 1           8064    Butterfinger Toffee Bark      1.000000
# 2           8064    Butterfinger Toffee Bark      1.000000
# 3           8064    Butterfinger Toffee Bark      1.000000
# 4           8064    Butterfinger Toffee Bark      1.000000
# ...          ...                         ...           ...
# 82936        757  One-Pan Breakfast Potatoes      0.968893
# 82937        757  One-Pan Breakfast Potatoes      0.968893
# 82938        757  One-Pan Breakfast Potatoes      0.968893
# 82939        757  One-Pan Breakfast Potatoes      0.968893
# 82940        757  One-Pan Breakfast Potatoes      0.968893
#
#        Recipe_positivevotes  Recipe_negativevotes  Recipe_totalvotes  \
# 0                         1                     0                  1
# 1                         1                     0                  1
# 2                         1                     0                  1
# 3                         1                     0                  1
# 4                         1                     0                  1
# ...                     ...                   ...                ...
# 82936                  1059                    34               1093
# 82937                  1059                    34               1093
# 82938                  1059                    34               1093
# 82939                  1059                    34               1093
# 82940                  1059                    34               1093
#
#       Recipe_country  Recipe_servings  \
# 0                 US                6
# 1                 US                6
# 2                 US                6
# 3                 US                6
# 4                 US                6
# ...              ...              ...
# 82936             US                4
# 82937             US                4
# 82938             US                4
# 82939             US                4
# 82940             US                4
#
#                                      Recipe_instructions  \
# 0      Preheat the oven to 400 °F. Line cookie sheet ...
# 1      Preheat the oven to 400 °F. Line cookie sheet ...
# 2      Preheat the oven to 400 °F. Line cookie sheet ...
# 3      Preheat the oven to 400 °F. Line cookie sheet ...
# 4      Preheat the oven to 400 °F. Line cookie sheet ...
# ...                                                  ...
# 82936  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82937  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82938  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82939  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82940  Preheat oven to 500˚F (260˚C). Dice potato, re...
#
#        Recipe_totalingredients  ... Recipe_fat  Recipe_fiber Recipe_sugar  \
# 0                            5  ...       55.0           4.0         48.0
# 1                            5  ...       55.0           4.0         48.0
# 2                            5  ...       55.0           4.0         48.0
# 3                            5  ...       55.0           4.0         48.0
# 4                            5  ...       55.0           4.0         48.0
# ...                        ...  ...        ...           ...          ...
# 82936                        9  ...        7.0           5.0          7.0
# 82937                        9  ...        7.0           5.0          7.0
# 82938                        9  ...        7.0           5.0          7.0
# 82939                        9  ...        7.0           5.0          7.0
# 82940                        9  ...        7.0           5.0          7.0
#
#                                             Recipe_video  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 82936  https://s3.amazonaws.com/video-api-prod/assets...
# 82937  https://s3.amazonaws.com/video-api-prod/assets...
# 82938  https://s3.amazonaws.com/video-api-prod/assets...
# 82939  https://s3.amazonaws.com/video-api-prod/assets...
# 82940  https://s3.amazonaws.com/video-api-prod/assets...
#
#                                              Recipe_tags   Country_tags  \
# 0      ['oven', 'indulgent_sweets', 'desserts', 'spec...            NaN
# 1      ['oven', 'indulgent_sweets', 'desserts', 'spec...            NaN
# 2      ['oven', 'indulgent_sweets', 'desserts', 'spec...            NaN
# 3      ['oven', 'indulgent_sweets', 'desserts', 'spec...            NaN
# 4      ['oven', 'indulgent_sweets', 'desserts', 'spec...            NaN
# ...                                                  ...            ...
# 82936  ['kid_friendly', 'american', 'healthy', 'easy'...  United States
# 82937  ['kid_friendly', 'american', 'healthy', 'easy'...  United States
# 82938  ['kid_friendly', 'american', 'healthy', 'easy'...  United States
# 82939  ['kid_friendly', 'american', 'healthy', 'easy'...  United States
# 82940  ['kid_friendly', 'american', 'healthy', 'easy'...  United States
#
#        Country_id  Unit_id  Ratings_id  Nutrition_id
# 0             NaN        0        8064          8064
# 1             NaN        1        8064          8064
# 2             NaN        1        8064          8064
# 3             NaN        1        8064          8064
# 4             NaN        4        8064          8064
# ...           ...      ...         ...           ...
# 82936        16.0       22         757           757
# 82937        16.0       22         757           757
# 82938        16.0       21         757           757
# 82939        16.0       21         757           757
# 82940        16.0       21         757           757
#
# [82941 rows x 28 columns]

# %% [markdown]
# ## Transform and Clean Data

# %%
df_recepies['Recipe_country'].describe()
# Out:
# count     82941
# unique        4
# top          US
# freq      72542
# Name: Recipe_country, dtype: object

# %%
df_recepies['Recipe_tags']
# Out:
# 0        ['oven', 'indulgent_sweets', 'desserts', 'spec...
# 1        ['oven', 'indulgent_sweets', 'desserts', 'spec...
# 2        ['oven', 'indulgent_sweets', 'desserts', 'spec...
# 3        ['oven', 'indulgent_sweets', 'desserts', 'spec...
# 4        ['oven', 'indulgent_sweets', 'desserts', 'spec...
#                                ...
# 82936    ['kid_friendly', 'american', 'healthy', 'easy'...
# 82937    ['kid_friendly', 'american', 'healthy', 'easy'...
# 82938    ['kid_friendly', 'american', 'healthy', 'easy'...
# 82939    ['kid_friendly', 'american', 'healthy', 'easy'...
# 82940    ['kid_friendly', 'american', 'healthy', 'easy'...
# Name: Recipe_tags, Length: 82941, dtype: object

# %%
type(df_recepies['Recipe_tags'].head(1).item())
# Out:
# str

# %% [markdown]
# ### Transform Tags from String to a List

# %%
def  tags (tags):
    '''
    Function return a list of tags, form string a list of tags in a recipe 
    
    Example1:
    tags = '['spatula', 'mixing_bowl', 'sauce_pan', 'desserts', 'deep_fry', 'indulgent_sweets', 
            'stove_top', 'sieve', 'tongs', 'dry_measuring_cups', 'liquid_measuring_cup', 
            'american', 'measuring_spoons', 'snacks', 'easy', 'kid_friendly', 'comfort_food', 
            'chefs_knife', 'cutting_board', 'pyrex', '3_musketeers']'
    return = ['spatula', 'mixing_bowl', 'sauce_pan', 'desserts', 'deep_fry', 'indulgent_sweets', 
            'stove_top', 'sieve', 'tongs', 'dry_measuring_cups', 'liquid_measuring_cup', 
            'american', 'measuring_spoons', 'snacks', 'easy', 'kid_friendly', 'comfort_food', 
            'chefs_knife', 'cutting_board', 'pyrex', '3_musketeers']
    Example2:
    tag = '['chinese', 'stove_top', 'chefs_knife', 'indulgent_sweets', 'measuring_spoons', 
           'saute_pan', 'liquid_measuring_cup', 'plastic_wrap', 'spatula', 'mixing_bowl', 
           'lunar_new_year', 'desserts']'
    return = ['chinese', 'stove_top', 'chefs_knife', 'indulgent_sweets', 'measuring_spoons', 
           'saute_pan', 'liquid_measuring_cup', 'plastic_wrap', 'spatula', 'mixing_bowl', 
           'lunar_new_year', 'desserts']
    '''
    tag=[tag.lower().replace(' ','').replace('_',' ') for tag in eval(tags)]
    return tag

# %%
df_recepies['Recipe_tags'] = df_recepies['Recipe_tags'].apply(tags)

# %%
type(df_recepies['Recipe_tags'].head(1).item())
# Out:
# list

# %% [markdown]
# ### Create Column Country from Tags

# %%
def  country (tags):
    '''
    Function return a country name, form a list of tags in a recipe 
    
    Example1:
    tags = ['spatula', 'mixing_bowl', 'sauce_pan', 'desserts', 'deep_fry', 'indulgent_sweets', 
            'stove_top', 'sieve', 'tongs', 'dry_measuring_cups', 'liquid_measuring_cup', 
            'american', 'measuring_spoons', 'snacks', 'easy', 'kid_friendly', 'comfort_food', 
            'chefs_knife', 'cutting_board', 'pyrex', '3_musketeers']
    return = United States
    Example2:
    tag = ['chinese', 'stove_top', 'chefs_knife', 'indulgent_sweets', 'measuring_spoons', 
           'saute_pan', 'liquid_measuring_cup', 'plastic_wrap', 'spatula', 'mixing_bowl', 
           'lunar_new_year', 'desserts']
    return = China
    '''
    tag_country={'vietnamese':'Vietnam','venezuelan':'Venezuela','thai':'Thailand','taiwanese':'Taiwan',
                 'swedish':'Sweden','south african':'South Africa','puerto rican':'Puerto Rico','peruvian':'Peru',
                 'persian':'Iran','mexican':'Mexico','lebanese':'Lebanon', 'laotian':'Laos','korean':'Korea',
                 'kenyan':'Kenya','japanese':'Japan','jamaican':'Jamaica', 'italian':'Italy','indian':'India',
                 'hawaiian':'United States','haitian':'Haiti', 'greek':'Greece','german':'Germany','french':'France',
                 'filipino':'Philippines','ethiopian':'Ethiopia', 'dominican':'Dominican Republic','cuban':'Cuba',
                 'chinese':'China','british':'United Kingdom','brazilian':'Brazil','american':'United States'}
    
    for tag in tags:
        if tag in tag_country.keys():
            country = tag_country[tag]
            return country

# %%
df_recepies['Country_tags'] = df_recepies['Recipe_tags'].apply(country)

# %%
df_recepies[df_recepies['Country_tags']=='United States']
# Out:
#        Recipe_id                    Recipe_name  Recipe_score  \
# 16          6456  Tasty 101 Edible Cookie Dough      0.897849
# 17          6456  Tasty 101 Edible Cookie Dough      0.897849
# 18          6456  Tasty 101 Edible Cookie Dough      0.897849
# 19          6456  Tasty 101 Edible Cookie Dough      0.897849
# 20          6456  Tasty 101 Edible Cookie Dough      0.897849
# ...          ...                            ...           ...
# 82936        757     One-Pan Breakfast Potatoes      0.968893
# 82937        757     One-Pan Breakfast Potatoes      0.968893
# 82938        757     One-Pan Breakfast Potatoes      0.968893
# 82939        757     One-Pan Breakfast Potatoes      0.968893
# 82940        757     One-Pan Breakfast Potatoes      0.968893
#
#        Recipe_positivevotes  Recipe_negativevotes  Recipe_totalvotes  \
# 16                      167                    19                186
# 17                      167                    19                186
# 18                      167                    19                186
# 19                      167                    19                186
# 20                      167                    19                186
# ...                     ...                   ...                ...
# 82936                  1059                    34               1093
# 82937                  1059                    34               1093
# 82938                  1059                    34               1093
# 82939                  1059                    34               1093
# 82940                  1059                    34               1093
#
#       Recipe_country  Recipe_servings  \
# 16                US                8
# 17                US                8
# 18                US                8
# 19                US                8
# 20                US                8
# ...              ...              ...
# 82936             US                4
# 82937             US                4
# 82938             US                4
# 82939             US                4
# 82940             US                4
#
#                                      Recipe_instructions  \
# 16     Preheat the oven to 350°F (180°C). Evenly spre...
# 17     Preheat the oven to 350°F (180°C). Evenly spre...
# 18     Preheat the oven to 350°F (180°C). Evenly spre...
# 19     Preheat the oven to 350°F (180°C). Evenly spre...
# 20     Preheat the oven to 350°F (180°C). Evenly spre...
# ...                                                  ...
# 82936  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82937  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82938  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82939  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82940  Preheat oven to 500˚F (260˚C). Dice potato, re...
#
#        Recipe_totalingredients  ... Recipe_fat  Recipe_fiber Recipe_sugar  \
# 16                          11  ...       19.0           4.0         48.0
# 17                          11  ...       19.0           4.0         48.0
# 18                          11  ...       19.0           4.0         48.0
# 19                          11  ...       19.0           4.0         48.0
# 20                          11  ...       19.0           4.0         48.0
# ...                        ...  ...        ...           ...          ...
# 82936                        9  ...        7.0           5.0          7.0
# 82937                        9  ...        7.0           5.0          7.0
# 82938                        9  ...        7.0           5.0          7.0
# 82939                        9  ...        7.0           5.0          7.0
# 82940                        9  ...        7.0           5.0          7.0
#
#                                             Recipe_video  \
# 16     https://s3.amazonaws.com/video-api-prod/assets...
# 17     https://s3.amazonaws.com/video-api-prod/assets...
# 18     https://s3.amazonaws.com/video-api-prod/assets...
# 19     https://s3.amazonaws.com/video-api-prod/assets...
# 20     https://s3.amazonaws.com/video-api-prod/assets...
# ...                                                  ...
# 82936  https://s3.amazonaws.com/video-api-prod/assets...
# 82937  https://s3.amazonaws.com/video-api-prod/assets...
# 82938  https://s3.amazonaws.com/video-api-prod/assets...
# 82939  https://s3.amazonaws.com/video-api-prod/assets...
# 82940  https://s3.amazonaws.com/video-api-prod/assets...
#
#                                              Recipe_tags   Country_tags  \
# 16     [one top app dessert, comfort food, hand mixer...  United States
# 17     [one top app dessert, comfort food, hand mixer...  United States
# 18     [one top app dessert, comfort food, hand mixer...  United States
# 19     [one top app dessert, comfort food, hand mixer...  United States
# 20     [one top app dessert, comfort food, hand mixer...  United States
# ...                                                  ...            ...
# 82936  [kid friendly, american, healthy, easy, bake, ...  United States
# 82937  [kid friendly, american, healthy, easy, bake, ...  United States
# 82938  [kid friendly, american, healthy, easy, bake, ...  United States
# 82939  [kid friendly, american, healthy, easy, bake, ...  United States
# 82940  [kid friendly, american, healthy, easy, bake, ...  United States
#
#        Country_id  Unit_id  Ratings_id  Nutrition_id
# 16           16.0        1        6456          6456
# 17           16.0        8        6456          6456
# 18           16.0        4        6456          6456
# 19           16.0        1        6456          6456
# 20           16.0        1        6456          6456
# ...           ...      ...         ...           ...
# 82936        16.0       22         757           757
# 82937        16.0       22         757           757
# 82938        16.0       21         757           757
# 82939        16.0       21         757           757
# 82940        16.0       21         757           757
#
# [26729 rows x 28 columns]

# %%
def countrytitle(title) :
    tag_country={'zambian':'Zambia','yemeni':'Yemen','vanuatuan':'Vanuatu','Uzbek':'Uzbekistan','uruguayan':'Uruguay','american':'United States',
                 'emirati':'United Arab Emirates','ukrainian':'Ukraine','ugandan':'Uganda','tuvaluan':'Tuvalu','turkoman':'Turkmenistan',
                 'turkish':'Turkey','tunisian':'Tunisia','trinidadian':'Trinidad and Tobago','togolese':'Togo','thai':'Thailand','tajik':'Tajikistan',
                 'swazi':'Swaziland','surinamese':'Suriname','sudanese':'Sudan','lankan':'Sri Lanka','south':'South Africa',
                 'somali':'Somalia','slomoni':'Solomon Islands','slovenian':'Slovenia','slovak':'Slovakia','singaporean':'Singapore',
                 'leonian':'Sierra Leone','serbian':'Serbia','senegalese':'Senegal','saudi arabian':'Saudi Arabia', 'rwandan':'Rwanda',
                 'romanian':'Romania','qatari':'Qatar','portuguese':'Portugal','polish':'Poland','peruvian':'Peru','paraguayan':'Paraguay',
                 'guinean':'Papua New Guinea','panamanian':'Panama','pakistani':'Pakistan','omani':'Oman','norwegian':'Norway','nigerian':'Nigeria',
                 'nigerien':'Niger','nicaraguan':'Nicaragua','zealand':'New Zealand','nepalese':'Nepal','namibian':'Namibia','mozambican':'Mozambique',
                 'moroccan':'Morocco','montenegrin':'Montenegro','mongolian':'Mongolia','monacan':'Monaco','mauritian':'Mauritius','mauritanian':'Mauritania',
                 'maltese':'Malta','malian':'Mali','maldivian':'Maldives','malaysian':'Malaysia','malawian':'Malawi','madagascan':'Madagascar','luxembourg':'Luxembourg',
                 'lithuanian':'Lithuania','libyan':'Libya','liberian':'Liberia','lebanese':'Lebanon','latvian':'Latvia','kuwaiti':'Kuwait', 'Korean':'Korea',
                 'kenyan':'Kenya','kazakh':'Kazakhstan','jordanian':'Jordan','jamaican':'Jamaica','iraqi':'Iraq','iranian':'Iran','persian':'Iran','indonesian':'Indonesia',
                 'icelandic':'Iceland','hungarian':'Hungary','guyanese':'Guyana','guinean':'Guinea','grenadian':'Grenada','greek':'Greece','ghanaian':'Ghana',
                 'georgian':'Georgia','gambian':'Gambia','gabonese':'Gabon','finnish':'Finland','fijian':'Fiji','ethiopian':'Ethiopia','estonian':'Estonia',
                 'eritrean':'Eritrea', 'egyptian':'Egypt','dominican':'Dominican Republic','danish':'Denmark','czech':'Czech Republic','cypriot':'Cyprus',
                 'croat': 'Croatia','rican':'Costa Rica','congolese':'Congo','chilean':'Chile','chadian':'Chad','cameroonian':'Cameroon','cambodian':'Cambodia',
                 'burundian':'Burundi','burkinese':'Burkina Faso','bulgarian':'Bulgaria','botswanan':'Botswana','bosnian':'Bosnia','bolivian':'Bolivia',
                 'bhutanese':'Bhutan','bermudian':'Bermuda','beninese':'Benin','belizean':'Belize','belarusian':'Belarus','barbadian':'Barbados','bangladeshi','Bangladesh',
                 'bahraini':'Bahrain','azerbaijani':'Azerbaijan','austrian':'Austria','armenian':'Armenia','angolan':'Angola','andorran':'Andorra',
                 'samoan':'Samoa','algerian':'Algeria',
                 



                }
    for tag in title.lower().split(' '):
        if tag in tag_country.keys():
            country = tag_country[tag]
            return country

# %%
df_recepies['Country_tags'].isna().sum()
# Out:
# 35391

# %%
df_recepies['Country_tags'] = np.where(df_recepies['Country_tags'].isna(),df_recepies['Recipe_name'].apply(countrytitle), df_recepies['Country_tags'])

# %%
df_recepies['Country_tags'].isna().sum()
# Out:
# 882

# %%
df_recepies['Country_tags'] = np.where(df_recepies['Country_tags'].isna(),
                                       np.where(df_recepies['Recipe_country']=='AU','Australia',
                                               np.where(df_recepies['Recipe_country']=='US','United States',
                                                       np.where(df_recepies['Recipe_country']=='GB','United Kingdom',None)))
                                       ,df_recepies['Country_tags'])

# %%
df_recepies[df_recepies['Country_tags']=='United States']
# Out:
#        Recipe_id                 Recipe_name  Recipe_score  \
# 0           8064    Butterfinger Toffee Bark      1.000000
# 1           8064    Butterfinger Toffee Bark      1.000000
# 2           8064    Butterfinger Toffee Bark      1.000000
# 3           8064    Butterfinger Toffee Bark      1.000000
# 4           8064    Butterfinger Toffee Bark      1.000000
# ...          ...                         ...           ...
# 82936        757  One-Pan Breakfast Potatoes      0.968893
# 82937        757  One-Pan Breakfast Potatoes      0.968893
# 82938        757  One-Pan Breakfast Potatoes      0.968893
# 82939        757  One-Pan Breakfast Potatoes      0.968893
# 82940        757  One-Pan Breakfast Potatoes      0.968893
#
#        Recipe_positivevotes  Recipe_negativevotes  Recipe_totalvotes  \
# 0                         1                     0                  1
# 1                         1                     0                  1
# 2                         1                     0                  1
# 3                         1                     0                  1
# 4                         1                     0                  1
# ...                     ...                   ...                ...
# 82936                  1059                    34               1093
# 82937                  1059                    34               1093
# 82938                  1059                    34               1093
# 82939                  1059                    34               1093
# 82940                  1059                    34               1093
#
#       Recipe_country  Recipe_servings  \
# 0                 US                6
# 1                 US                6
# 2                 US                6
# 3                 US                6
# 4                 US                6
# ...              ...              ...
# 82936             US                4
# 82937             US                4
# 82938             US                4
# 82939             US                4
# 82940             US                4
#
#                                      Recipe_instructions  \
# 0      Preheat the oven to 400 °F. Line cookie sheet ...
# 1      Preheat the oven to 400 °F. Line cookie sheet ...
# 2      Preheat the oven to 400 °F. Line cookie sheet ...
# 3      Preheat the oven to 400 °F. Line cookie sheet ...
# 4      Preheat the oven to 400 °F. Line cookie sheet ...
# ...                                                  ...
# 82936  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82937  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82938  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82939  Preheat oven to 500˚F (260˚C). Dice potato, re...
# 82940  Preheat oven to 500˚F (260˚C). Dice potato, re...
#
#        Recipe_totalingredients  ... Recipe_fat  Recipe_fiber Recipe_sugar  \
# 0                            5  ...       55.0           4.0         48.0
# 1                            5  ...       55.0           4.0         48.0
# 2                            5  ...       55.0           4.0         48.0
# 3                            5  ...       55.0           4.0         48.0
# 4                            5  ...       55.0           4.0         48.0
# ...                        ...  ...        ...           ...          ...
# 82936                        9  ...        7.0           5.0          7.0
# 82937                        9  ...        7.0           5.0          7.0
# 82938                        9  ...        7.0           5.0          7.0
# 82939                        9  ...        7.0           5.0          7.0
# 82940                        9  ...        7.0           5.0          7.0
#
#                                             Recipe_video  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 82936  https://s3.amazonaws.com/video-api-prod/assets...
# 82937  https://s3.amazonaws.com/video-api-prod/assets...
# 82938  https://s3.amazonaws.com/video-api-prod/assets...
# 82939  https://s3.amazonaws.com/video-api-prod/assets...
# 82940  https://s3.amazonaws.com/video-api-prod/assets...
#
#                                              Recipe_tags   Country_tags  \
# 0      [oven, indulgent sweets, desserts, special occ...  United States
# 1      [oven, indulgent sweets, desserts, special occ...  United States
# 2      [oven, indulgent sweets, desserts, special occ...  United States
# 3      [oven, indulgent sweets, desserts, special occ...  United States
# 4      [oven, indulgent sweets, desserts, special occ...  United States
# ...                                                  ...            ...
# 82936  [kid friendly, american, healthy, easy, bake, ...  United States
# 82937  [kid friendly, american, healthy, easy, bake, ...  United States
# 82938  [kid friendly, american, healthy, easy, bake, ...  United States
# 82939  [kid friendly, american, healthy, easy, bake, ...  United States
# 82940  [kid friendly, american, healthy, easy, bake, ...  United States
#
#        Country_id  Unit_id  Ratings_id  Nutrition_id
# 0             NaN        0        8064          8064
# 1             NaN        1        8064          8064
# 2             NaN        1        8064          8064
# 3             NaN        1        8064          8064
# 4             NaN        4        8064          8064
# ...           ...      ...         ...           ...
# 82936        16.0       22         757           757
# 82937        16.0       22         757           757
# 82938        16.0       21         757           757
# 82939        16.0       21         757           757
# 82940        16.0       21         757           757
#
# [60287 rows x 28 columns]

# %%
df_recepies['Country_tags'].unique()
# Out:
# array(['United States', 'Mexico', 'France', 'Italy', 'Greece', 'Korea',
#        'Taiwan', 'China', 'United Kingdom', 'Venezuela', 'India', None,
#        'Japan', 'Kenya', 'Germany', 'Brazil', 'Philippines',
#        'Dominican Republic', 'Sweden', 'Ethiopia', 'Vietnam', 'Thailand',
#        'Haiti', 'Cuba', 'Puerto Rico', 'Iran', 'Lebanon', 'Jamaica',
#        'Peru', 'South Africa', 'Laos'], dtype=object)

# %%
df_recepies['Country_tags'].isna().sum()
# Out:
# 882

# %% [markdown]
# ## Create DataFrames to export as tables to SQL

# %%
df_recepies['Len_tags'] = np.where(df_recepies['Recipe_tags'].notna(), df_recepies['Recipe_tags'].str.len(),0)
df_recepies['Len_tags'].describe()
# Out:
# count    82941.000000
# mean        16.308629
# std          6.134221
# min          1.000000
# 25%         12.000000
# 50%         17.000000
# 75%         21.000000
# max         36.000000
# Name: Len_tags, dtype: float64

# %%
recepies_tags = pd.DataFrame(df_recepies['Recipe_tags'].tolist(), columns=['tag1', 'tag2','tag3', 'tag4','tag5', 'tag6','tag7', 'tag8',
                                                                                         'tag9', 'tag10','tag11', 'tag12','tag13', 'tag14','tag15', 'tag16',
                                                                                         'tag17', 'tag18','tag19', 'tag20','tag21', 'tag22','tag23', 'tag24',
                                                                                         'tag25', 'tag26','tag27', 'tag28','tag29', 'tag30','tag31', 'tag32',
                                                                                         'tag33', 'tag34','tag35', 'tag36'])
recepie_tags = pd.concat([df_recepies[['Recipe_id']], recepies_tags], axis=1)
recepie_tags = recepie_tags.dropna(axis=1,how='all')
recepie_tags = recepie_tags.dropna(axis=0,how='all')
recepie_tags = recepie_tags.drop_duplicates()
recepie_tags
# Out:
#        Recipe_id                         tag1              tag2  \
# 0           8064                         oven  indulgent sweets
# 5           6445  tasty s 5th birthday recipe       mixing bowl
# 16          6456          one top app dessert      comfort food
# 27          5487             indulgent sweets              oven
# 40          4197               food processor        baking pan
# ...          ...                          ...               ...
# 82854       4847                         oven      comfort food
# 82893       3337                         bake             whisk
# 82907       3181                       fusion              oven
# 82914       2958                  slow cooker          american
# 82926        511                 kid friendly            brunch
#
#                        tag3              tag4              tag5  \
# 0                  desserts  special occasion              bake
# 5                    spider       cupcake pan          desserts
# 16               hand mixer          american   ice cream scoop
# 27     liquid measuring cup      bakery goods          desserts
# 40               hand mixer      cooling rack  indulgent sweets
# ...                     ...               ...               ...
# 82854      measuring spoons       mixing bowl        baking pan
# 82893      measuring spoons         meal prep         breakfast
# 82907                french      comfort food          american
# 82914             big batch              easy         breakfast
# 82926             breakfast              oven              bake
#
#                               tag6            tag7              tag8  \
# 0      butterfinger runner up bark            None              None
# 5                         deep fry       stove top  indulgent sweets
# 16      tasty s 5th birthday sweet        desserts              bake
# 27                  offset spatula           whisk        oven mitts
# 40              dry measuring cups        desserts              oven
# ...                            ...             ...               ...
# 82854         liquid measuring cup    wooden spoon              easy
# 82893                  mixing bowl    kid friendly        oven mitts
# 82907                         easy       stove top         sauce pan
# 82914                 kid friendly  one pot or pan            brunch
# 82926                         easy        american      comfort food
#
#                        tag9  ... tag27 tag28 tag29 tag30 tag31 tag32 tag33  \
# 0                      None  ...  None  None  None  None  None  None  None
# 5                   mexican  ...  None  None  None  None  None  None  None
# 16         indulgent sweets  ...  None  None  None  None  None  None  None
# 27                  spatula  ...  None  None  None  None  None  None  None
# 40                   french  ...  None  None  None  None  None  None  None
# ...                     ...  ...   ...   ...   ...   ...   ...   ...   ...
# 82854             christmas  ...  None  None  None  None  None  None  None
# 82893                  easy  ...  None  None  None  None  None  None  None
# 82907               spatula  ...  None  None  None  None  None  None  None
# 82914  liquid measuring cup  ...  None  None  None  None  None  None  None
# 82926                summer  ...  None  None  None  None  None  None  None
#
#       tag34 tag35 tag36
# 0      None  None  None
# 5      None  None  None
# 16     None  None  None
# 27     None  None  None
# 40     None  None  None
# ...     ...   ...   ...
# 82854  None  None  None
# 82893  None  None  None
# 82907  None  None  None
# 82914  None  None  None
# 82926  None  None  None
#
# [3526 rows x 37 columns]

# %%
tags_name = list(tags_name)
tags_name = [tag.lower().replace(' ','-').replace('_',' ') for tag in tags_name]
tags = pd.DataFrame({'Tag_Name': tags_name})
tags = tags.dropna()
tags = tags.drop_duplicates()
tags['Tag_id'] = tags.index
tags
# Out:
#                         Tag_Name  Tag_id
# 0                      christmas       0
# 1                     microplane       1
# 2           mc-breakfast-healthy       2
# 3                          steam       3
# 4                     oh-so-rose       4
# ..                           ...     ...
# 296                 kid-friendly     296
# 297                   nynm-money     297
# 298           mc-breakfast-sweet     298
# 299  mccormick-ugc-one-pot-pasta     299
# 300                  gluten-free     300
#
# [301 rows x 2 columns]

# %%
df_recepies = df_recepies.drop('Country_id', axis = 1)
country = df_recepies[['Country_tags']]
country = country.dropna()
country= country.drop_duplicates()
country['Country_id'] = country.index
df_recepies = df_recepies.join(country.set_index('Country_tags'), on='Country_tags')
country
# Out:
#              Country_tags  Country_id
# 0           United States           0
# 5                  Mexico           5
# 40                 France          40
# 99                  Italy          99
# 380                Greece         380
# 597                 Korea         597
# 610                Taiwan         610
# 622                 China         622
# 710        United Kingdom         710
# 758             Venezuela         758
# 844                 India         844
# 1696                Japan        1696
# 2298                Kenya        2298
# 2449              Germany        2449
# 4827               Brazil        4827
# 5201          Philippines        5201
# 5300   Dominican Republic        5300
# 5556             Ethiopia        5556
# 5745              Vietnam        5745
# 6334             Thailand        6334
# 7245                Haiti        7245
# 7553                 Cuba        7553
# 8150          Puerto Rico        8150
# 11052                Iran       11052
# 14009              Sweden       14009
# 14132             Lebanon       14132
# 17844             Jamaica       17844
# 23552                Peru       23552
# 34548        South Africa       34548
# 45967                Laos       45967

# %%
df_recepies = df_recepies.drop('Unit_id', axis = 1)
measurements = df_recepies[['Unit_name']]
measurements= measurements.drop_duplicates()
measurements['Unit_id'] = measurements.index
df_recepies = df_recepies.join(measurements.set_index('Unit_name'), on='Unit_name')
measurements
# Out:
#          Unit_name  Unit_id
# 0            ounce        0
# 1              cup        1
# 4              NaN        4
# 8            stick        8
# 12           quart       12
# ...            ...      ...
# 54381       cookie    54381
# 55484  small stalk    55484
# 62695       banana    62695
# 69926      serving    69926
# 76772       fillet    76772
#
# [119 rows x 2 columns]

# %%
ingredients = df_recepies[['Ingredient_id','Ingredient_name']]
ingredients= ingredients.drop_duplicates()
ingredients
# Out:
#        Ingredient_id              Ingredient_name
# 0               6533             saltine crackers
# 1                 30                       butter
# 2                824             dark brown sugar
# 3               3871     semisweet chocolate chip
# 4               9484         crushed Butterfinger
# ...              ...                          ...
# 82768           1298     chocolate protein powder
# 82769           2518  dark chocolate cocoa powder
# 82777           3059                      dry oat
# 82783           2297                  vanilla pod
# 82863           4936  day-old country white bread
#
# [4023 rows x 2 columns]

# %%
recipes = df_recepies[['Recipe_id','Recipe_name','Recipe_servings','Recipe_instructions','Recipe_totalingredients','Recipe_video','Recipe_tags','Country_id']]
recipes= recipes.drop_duplicates(subset=['Recipe_id','Recipe_name','Recipe_servings','Recipe_instructions','Recipe_totalingredients','Recipe_video','Country_id'])
recipes
# Out:
#        Recipe_id                               Recipe_name  Recipe_servings  \
# 0           8064                  Butterfinger Toffee Bark                6
# 5           6445  Cookies And Cream Churro Ice Cream Bowls                6
# 16          6456             Tasty 101 Edible Cookie Dough                8
# 27          5487                              Volcano Cake               20
# 40          4197                      How To Make Macarons               30
# ...          ...                                       ...              ...
# 82854       4847  Cheddar, Sausage, And Egg Breakfast Bake               12
# 82893       3337           Make-Ahead Breakfast Enchiladas                8
# 82907       3181        Egg-In-Hole Layered Breakfast Bake                6
# 82914       2958           Sausage And Egg Breakfast Tacos                8
# 82926        511                               Bagel Boats                1
#
#                                      Recipe_instructions  \
# 0      Preheat the oven to 400 °F. Line cookie sheet ...
# 5      Separate the chocolate sandwich cookies from t...
# 16     Preheat the oven to 350°F (180°C). Evenly spre...
# 27     Preheat the oven to 350˚F (180˚C). Grease and ...
# 40     Make the macarons: In the bowl of a food proce...
# ...                                                  ...
# 82854  Add the breakfast sausage to a large nonstick ...
# 82893  In a large bowl, combine bacon, 2 cups (200 gr...
# 82907  Preheat the oven broiler to high. Line a bakin...
# 82914  Layer the potatoes on the bottom of a greased ...
# 82926  Preheat oven to 375°F (190°C). In a small bowl...
#
#        Recipe_totalingredients  \
# 0                            5
# 5                           11
# 16                          11
# 27                          13
# 40                           7
# ...                        ...
# 82854                       13
# 82893                       14
# 82907                        7
# 82914                       12
# 82926                        6
#
#                                             Recipe_video  \
# 0                                                    NaN
# 5      https://s3.amazonaws.com/video-api-prod/assets...
# 16     https://s3.amazonaws.com/video-api-prod/assets...
# 27     https://s3.amazonaws.com/video-api-prod/assets...
# 40     https://s3.amazonaws.com/video-api-prod/assets...
# ...                                                  ...
# 82854  https://s3.amazonaws.com/video-api-prod/assets...
# 82893  https://s3.amazonaws.com/video-api-prod/assets...
# 82907  https://s3.amazonaws.com/video-api-prod/assets...
# 82914  https://s3.amazonaws.com/video-api-prod/assets...
# 82926  https://s3.amazonaws.com/video-api-prod/assets...
#
#                                              Recipe_tags  Country_id
# 0      [oven, indulgent sweets, desserts, special occ...         0.0
# 5      [tasty s 5th birthday recipe, mixing bowl, spi...         5.0
# 16     [one top app dessert, comfort food, hand mixer...         0.0
# 27     [indulgent sweets, oven, liquid measuring cup,...         0.0
# 40     [food processor, baking pan, hand mixer, cooli...        40.0
# ...                                                  ...         ...
# 82854  [oven, comfort food, measuring spoons, mixing ...         0.0
# 82893  [bake, whisk, measuring spoons, meal prep, bre...         0.0
# 82907  [fusion, oven, french, comfort food, american,...        40.0
# 82914  [slow cooker, american, big batch, easy, break...         0.0
# 82926  [kid friendly, brunch, breakfast, oven, bake, ...         0.0
#
# [3526 rows x 8 columns]

# %%
df_recepies['Ratings_id']= df_recepies['Recipe_id']
df_recepies['Nutrition_id']= df_recepies['Recipe_id']

# %%
ratings = df_recepies[['Ratings_id','Recipe_score','Recipe_positivevotes','Recipe_negativevotes','Recipe_totalvotes']]
ratings= ratings.drop_duplicates(subset='Ratings_id')
ratings
# Out:
#        Ratings_id  Recipe_score  Recipe_positivevotes  Recipe_negativevotes  \
# 0            8064      1.000000                     1                     0
# 5            6445      0.899371                   143                    16
# 16           6456      0.897849                   167                    19
# 27           5487      0.821429                   161                    35
# 40           4197      0.873721                  8282                  1197
# ...           ...           ...                   ...                   ...
# 82854        4847      0.934783                   172                    12
# 82893        3337      0.911330                   185                    18
# 82907        3181      0.890411                    65                     8
# 82914        2958      0.812500                    26                     6
# 82926         511      0.915842                   185                    17
#
#        Recipe_totalvotes
# 0                      1
# 5                    159
# 16                   186
# 27                   196
# 40                  9479
# ...                  ...
# 82854                184
# 82893                203
# 82907                 73
# 82914                 32
# 82926                202
#
# [3526 rows x 5 columns]

# %%
nutrition = df_recepies[['Nutrition_id','Recipe_calories','Recipe_carbohydrates','Recipe_protein','Recipe_fat','Recipe_fiber','Recipe_sugar']]
nutrition= nutrition.drop_duplicates(subset='Nutrition_id')
nutrition
# Out:
#        Nutrition_id  Recipe_calories  Recipe_carbohydrates  Recipe_protein  \
# 0              8064            760.0                  71.0             6.0
# 5              6445              NaN                   NaN             NaN
# 16             6456            558.0                  95.0             8.0
# 27             5487            742.0                 129.0             3.0
# 40             4197            173.0                  21.0             1.0
# ...             ...              ...                   ...             ...
# 82854          4847            496.0                  39.0            22.0
# 82893          3337            935.0                  33.0            59.0
# 82907          3181            648.0                  15.0            42.0
# 82914          2958            429.0                  18.0            27.0
# 82926           511            894.0                  52.0            59.0
#
#        Recipe_fat  Recipe_fiber  Recipe_sugar
# 0            55.0           4.0          48.0
# 5             NaN           NaN           NaN
# 16           19.0           4.0          48.0
# 27           26.0           1.0          98.0
# 40            9.0           0.0          19.0
# ...           ...           ...           ...
# 82854        28.0           2.0           7.0
# 82893        61.0           1.0           4.0
# 82907        45.0           0.0           5.0
# 82914        27.0           1.0           3.0
# 82926        48.0           1.0           9.0
#
# [3526 rows x 7 columns]

# %%
ingredientsquantitymeasurments = df_recepies[['Recipe_id','Ingredient_id','Unit_id','Ingredient_quantity','Ingredient_name','Unit_name','Ingredient_text']]
ingredientsquantitymeasurments= ingredientsquantitymeasurments.drop_duplicates()
ingredientsquantitymeasurments
# Out:
#        Recipe_id  Ingredient_id  Unit_id Ingredient_quantity  \
# 0           8064           6533        0                   4
# 1           8064             30        1                   1
# 2           8064            824        1                   1
# 3           8064           3871        1                   2
# 4           8064           9484        4                   ¾
# ...          ...            ...      ...                 ...
# 82927        511             19        4                   2
# 82928        511            434       22                   2
# 82929        511            214      133                   2
# 82930        511            255       22                   1
# 82931        511             21       22                   1
#
#                 Ingredient_name   Unit_name                   Ingredient_text
# 0              saltine crackers       ounce         4 ounces saltine crackers
# 1                        butter         cup                      1 cup butter
# 2              dark brown sugar         cup            1 cup dark brown sugar
# 3      semisweet chocolate chip         cup  2 cups semisweet chocolate chips
# 4          crushed Butterfinger         NaN            ¾ crushed Butterfinger
# ...                         ...         ...                               ...
# 82927                       egg         NaN                            2 eggs
# 82928            cheddar cheese  tablespoon      2 tablespoons cheddar cheese
# 82929                     bacon       strip       2 strips of bacon (chopped)
# 82930               green onion  tablespoon          1 tablespoon green onion
# 82931                      milk  tablespoon                 1 tablespoon milk
#
# [30471 rows x 7 columns]

# %%
df_recepies.to_csv('country.csv')
df_recepies.to_csv('measurements.csv')
df_recepies.to_csv('ingredients.csv')
df_recepies.to_csv('recipes.csv')
df_recepies.to_csv('ratings.csv')
df_recepies.to_csv('nutrition.csv')
df_recepies.to_csv('ingredientsquantitymeasurments.csv')
df_recepies.to_csv('tags.csv')
df_recepies.to_csv('recepie_tags')

# %%
df_recepies.to_csv('Tasty_recepies.csv')

# %% [markdown]
# # Importa DataSets to SQL Postgres

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://ironhack_project:123456@localhost:5432/tasty')

# %%
conection = engine.connect()

# %%
country= country.rename(columns={'Country_tags':'country_tags','Country_id':'country_id'})
ingredients= ingredients.rename(columns={'Ingredient_id':'ingredient_id','Ingredient_name':'ingredient_name'})
measurements= measurements.rename(columns={'Unit_id':'unit_id','Unit_name':'unit_name'})
ratings= ratings.rename(columns={'Ratings_id':'ratings_id','Recipe_score':'recipe_score','Recipe_positivevotes':'recipe_positivevotes','Recipe_negativevotes':'recipe_negativevotes','Recipe_totalvotes':'recipe_totalvotes'})
nutrition= nutrition.rename(columns={'Nutrition_id':'nutrition_id','Recipe_calories':'recipe_calories','Recipe_carbohydrates':'recipe_carbohydrates','ecipe_protein':'recipe_protein','Recipe_fat':'recipe_fat','Recipe_fiber':'recipe_fiber','Recipe_sugar':'recipe_sugar'})
recipes= recipes.rename(columns={'Recipe_id':'recipe_id','Recipe_name':'recipe_name','Recipe_servings':'recipe_servings','Recipe_instructions':'recipe_instructions','Recipe_totalingredients':'Recipe_totalingredients','Recipe_video':'recipe_video','Recipe_tags':'recipe_tags','Country_id':'country_id'})
ingredientsquantitymeasurments = ingredientsquantitymeasurments.rename(columns={'Recipe_id':'recipe_id','Ingredient_id':'ingredient_id','Unit_id':'unit_id','Ingredient_quantity':'ingredient_quantity','Ingredient_name':'ingredient_name','Unit_name':'unit_name','Ingredient_text':'ingredient_text'})
tags= tags.rename(columns={'Tag_Name':'tag_name','Tag_id':'tag_id'})
recepie_tags = recepie_tags.rename(columns={'Recipe_id':'recipe_id'})

# %%
country.to_sql(name='country',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
ingredients.to_sql(name='ingredients',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
measurements.to_sql(name='measurements',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
ratings.to_sql(name='ratings',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
nutrition.to_sql(name='nutrition',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
recipes.to_sql(name='recipes',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
ingredientsquantitymeasurments.to_sql(name='ingredientsquantitymeasurments',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
tags.to_sql(name='tags',con=conection, if_exists='replace' ,index=False, schema='public')

# %%
recepie_tags.to_sql(name='recepie_tags',con=conection, if_exists='replace' ,index=False, schema='public')
