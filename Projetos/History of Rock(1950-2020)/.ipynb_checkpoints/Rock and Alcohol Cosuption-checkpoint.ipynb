# %% [markdown]
# # 1 Import Librerys
# ## Import Pandas and Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2 Read Data Sets

# %% [markdown]
# ## DataSet global alcohol consuption per capital in liters
# ### Review and read datset

# %%
file = open('C:/Users/forqu/OneDrive/Documentos/IronHack/Github/Projetos/History of Rock(1950-2020)/Data/Alcohol, record per capital (15+) consuption (World Health organization).csv', 'rb')
file_lines = file.readlines(10000)
for i in range(5):
    print(file_lines[i].decode('UTF-8'))
file.close()
Alcoholconsuption=pd.read_csv('C:/Users/forqu/OneDrive/Documentos/IronHack/Github/Projetos/History of Rock(1950-2020)/Data/Alcohol, record per capital (15+) consuption (World Health organization).csv', sep = ',', decimal = '.', encoding = 'UTF-8')
# Out:
# IndicatorCode,Indicator,ValueType,ParentLocationCode,ParentLocation,Location type,SpatialDimValueCode,Location,Period type,Period,IsLatestYear,Dim1 type,Dim1,Dim1ValueCode,Dim2 type,Dim2,Dim2ValueCode,Dim3 type,Dim3,Dim3ValueCode,DataSourceDimValueCode,DataSource,FactValueNumericPrefix,FactValueNumeric,FactValueUoM,FactValueNumericLowPrefix,FactValueNumericLow,FactValueNumericHighPrefix,FactValueNumericHigh,Value,FactValueTranslationID,FactComments,Language,DateModified
#
# SA_0000001400,"Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)",numeric,EMR,Eastern Mediterranean,Country,AFG,Afghanistan,Year,2019,true,Beverage Types,Beer,SA_BEER,,,,,,,GISAHAFG,Data source,,0,,,0,,0,0 [0 – 0],,,EN,2021-04-29T03:00:00.000Z
#
# SA_0000001400,"Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)",numeric,EMR,Eastern Mediterranean,Country,AFG,Afghanistan,Year,2019,true,Beverage Types,Wine,SA_WINE,,,,,,,GISAHCUB,Data source,,0,,,0,,0,0 [0 – 0],,,EN,2021-04-29T03:00:00.000Z
#
# SA_0000001400,"Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)",numeric,EMR,Eastern Mediterranean,Country,AFG,Afghanistan,Year,2019,true,Beverage Types,Other alcoholic beverages,SA_OTHER_ALCOHOL,,,,,,,GISAHNIU,Data source,,0,,,0,,0,0 [0 – 0],,,EN,2021-04-29T03:00:00.000Z
#
# SA_0000001400,"Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)",numeric,AFR,Africa,Country,DZA,Algeria,Year,2019,true,Beverage Types,Other alcoholic beverages,SA_OTHER_ALCOHOL,,,,,,,GISAHPNG,Data source,,0,,,0,,0,0 [0 – 0],,,EN,2021-04-29T03:00:00.000Z
# C:\Users\forqu\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Clean DataSet Alcohol consuption

# %%
alcoholconsuption = Alcoholconsuption[['ParentLocation','Location','Period','Dim1','FactValueNumeric']]
alcoholconsuption = alcoholconsuption.rename(columns={"ParentLocation":"Region","Location": "Country", "Period": "Year", "Dim1" : "Alcohol_type", "FactValueNumeric":"Alcohol_consuption_lts"})
alcoholconsuption['Alcohol_type'] = np.where(alcoholconsuption['Alcohol_type'] == 'Other alcoholic beverages', 'Others', alcoholconsuption['Alcohol_type'])
alcoholconsuption
# Out:
#                       Region                   Country  Year Alcohol_type  \
# 0      Eastern Mediterranean               Afghanistan  2019         Beer
# 1      Eastern Mediterranean               Afghanistan  2019         Wine
# 2      Eastern Mediterranean               Afghanistan  2019       Others
# 3                     Africa                   Algeria  2019       Others
# 4                     Europe                   Andorra  2019       Others
# ...                      ...                       ...   ...          ...
# 47789               Americas  United States of America  1960      Spirits
# 47790               Americas  United States of America  1960         Beer
# 47791                 Europe                   Austria  1960         Beer
# 47792               Americas  United States of America  1960    All types
# 47793                 Europe                   Austria  1960    All types
#
#        Alcohol_consuption_lts
# 0                        0.00
# 1                        0.00
# 2                        0.00
# 3                        0.00
# 4                        0.00
# ...                       ...
# 47789                    3.26
# 47790                    3.75
# 47791                    4.70
# 47792                    7.83
# 47793                    8.91
#
# [47794 rows x 5 columns]

# %% [markdown]
# ## DataSet global deaths related to alcohol
#
# ### Review and read datset

# %%
file = open('C:/Users/forqu/OneDrive/Documentos/IronHack/Github/Projetos/History of Rock(1950-2020)/Data/deaths-attributed-to-alcohol-use-by-age.csv', 'rb')
file_lines = file.readlines(10000)
for i in range(5):
    print(file_lines[i].decode('latin-1'))
file.close()
alcoholdeath= pd.read_csv('C:/Users/forqu/OneDrive/Documentos/IronHack/Github/Projetos/History of Rock(1950-2020)/Data/deaths-attributed-to-alcohol-use-by-age.csv', sep = ',', decimal = '.', encoding = 'latin-1')
# Out:
# Entity,Code,Year,Deaths - Alcohol use - Sex: Both - Age: Under 5 (Number),Deaths - Alcohol use - Sex: Both - Age: 70+ years (Number),Deaths - Alcohol use - Sex: Both - Age: 50-69 years (Number),Deaths - Alcohol use - Sex: Both - Age: 5-14 years (Number),Deaths - Alcohol use - Sex: Both - Age: 15-49 years (Number)
#
# Afghanistan,AFG,1990,,-1.232956300822979,159.04498244362145,0.6385758543491409,198.07870486400262
#
# Afghanistan,AFG,1991,,-9.539797075377507,134.0888083703571,0.6311983910085259,195.4182515455558
#
# Afghanistan,AFG,1992,,-17.965002061538605,107.2565425162102,0.6973421420969111,203.26813362016617
#
# Afghanistan,AFG,1993,,-24.962000080906414,83.88873473112277,0.8252449233497208,218.37777875272883

# %% [markdown]
# ### Clean DataSet deaths related to alcohol

# %%
alcoholdeath = alcoholdeath.rename(columns={"Entity":"Country","Code":"Country_cod","Deaths - Alcohol use - Sex: Both - Age: Under 5 (Number)":"Deaths_Under_5", "Deaths - Alcohol use - Sex: Both - Age: 70+ years (Number)": "Deaths_70+_years", "Deaths - Alcohol use - Sex: Both - Age: 50-69 years (Number)":"Deaths_50-69_years","Deaths - Alcohol use - Sex: Both - Age: 5-14 years (Number)":"Deaths_5-14_years","Deaths - Alcohol use - Sex: Both - Age: 15-49 years (Number)":"Deaths_15-49_years"})
alcoholdeath = alcoholdeath[['Country_cod','Country','Year','Deaths_Under_5','Deaths_5-14_years','Deaths_15-49_years','Deaths_50-69_years','Deaths_70+_years']]
alcoholdeath
# Out:
#      Country_cod      Country  Year  Deaths_Under_5  Deaths_5-14_years  \
# 0            AFG  Afghanistan  1990             NaN           0.638576
# 1            AFG  Afghanistan  1991             NaN           0.631198
# 2            AFG  Afghanistan  1992             NaN           0.697342
# 3            AFG  Afghanistan  1993             NaN           0.825245
# 4            AFG  Afghanistan  1994             NaN           0.884239
# ...          ...          ...   ...             ...                ...
# 6463         ZWE     Zimbabwe  2013             NaN           8.255216
# 6464         ZWE     Zimbabwe  2014             NaN           8.263859
# 6465         ZWE     Zimbabwe  2015             NaN           8.269672
# 6466         ZWE     Zimbabwe  2016             NaN           8.436222
# 6467         ZWE     Zimbabwe  2017             NaN           8.660342
#
#       Deaths_15-49_years  Deaths_50-69_years  Deaths_70+_years
# 0             198.078705          159.044982         -1.232956
# 1             195.418252          134.088808         -9.539797
# 2             203.268134          107.256543        -17.965002
# 3             218.377779           83.888735        -24.962000
# 4             217.774814           62.871469        -30.838953
# ...                  ...                 ...               ...
# 6463         3978.030287         2697.983429        693.610019
# 6464         3869.847618         2643.759805        680.263028
# 6465         3852.269669         2634.610126        679.470620
# 6466         3838.990911         2642.607539        684.563339
# 6467         3845.341395         2676.021575        697.961898
#
# [6468 rows x 8 columns]

# %% [markdown]
# Treat NaNs in death columns and convert all numerical values in positive integers values

# %%
def num(value):
    """
    This funtion return any numeircal value as a positive integer number and any NaNs values as integer 0
    
    Example :
        Input: "-9.539797"
        Return: "10"
        
    Example1 :
        Input: "NaN"
        Return: "0"
    """
    
    if value < 0 :
        value = -value
        return int(round(value,0))
    elif value >= 0 :
        return int(round(value,0))
    else :
        value = 0
        return int(round(value,0))

# %%
alcoholdeath['Deaths_Under_5']= alcoholdeath['Deaths_Under_5'].apply(num)
alcoholdeath['Deaths_5-14_years']= alcoholdeath['Deaths_5-14_years'].apply(num)
alcoholdeath['Deaths_15-49_years']= alcoholdeath['Deaths_15-49_years'].apply(num)
alcoholdeath['Deaths_50-69_years']= alcoholdeath['Deaths_50-69_years'].apply(num)
alcoholdeath['Deaths_70+_years']= alcoholdeath['Deaths_70+_years'].apply(num)
# Create Colum Total Deaths 
alcoholdeath['Total_deaths'] = alcoholdeath['Deaths_Under_5']+alcoholdeath['Deaths_5-14_years']+alcoholdeath['Deaths_15-49_years']+alcoholdeath['Deaths_50-69_years']+alcoholdeath['Deaths_70+_years']
alcoholdeath
# Out:
#      Country_cod      Country  Year  Deaths_Under_5  Deaths_5-14_years  \
# 0            AFG  Afghanistan  1990               0                  1
# 1            AFG  Afghanistan  1991               0                  1
# 2            AFG  Afghanistan  1992               0                  1
# 3            AFG  Afghanistan  1993               0                  1
# 4            AFG  Afghanistan  1994               0                  1
# ...          ...          ...   ...             ...                ...
# 6463         ZWE     Zimbabwe  2013               0                  8
# 6464         ZWE     Zimbabwe  2014               0                  8
# 6465         ZWE     Zimbabwe  2015               0                  8
# 6466         ZWE     Zimbabwe  2016               0                  8
# 6467         ZWE     Zimbabwe  2017               0                  9
#
#       Deaths_15-49_years  Deaths_50-69_years  Deaths_70+_years  Total_deaths
# 0                    198                 159                 1           359
# 1                    195                 134                10           340
# 2                    203                 107                18           329
# 3                    218                  84                25           328
# 4                    218                  63                31           313
# ...                  ...                 ...               ...           ...
# 6463                3978                2698               694          7378
# 6464                3870                2644               680          7202
# 6465                3852                2635               679          7174
# 6466                3839                2643               685          7175
# 6467                3845                2676               698          7228
#
# [6468 rows x 9 columns]

# %%
shark_per_country = sharkfatal.groupby('country').agg(
    first_year=pd.NamedAgg('year', 'min'),
    last_year=pd.NamedAgg('year', 'max'),
    attacks_country=pd.NamedAgg('fatal', 'count'),
    fatal_country=pd.NamedAgg('fatal_y', 'sum'))
shark_per_country.sort_values('attacks_country', ascending=False).T

alcoholdeathperyear = alcoholdeath.groupby(['Year']).agg(
    total_global_deaths = pd.NamedAgg('Total_deaths', 'sum'))
alcoholdeathperyear = alcoholdeath.merge(alcoholdeathperyear, on=['Year'])
alcoholdeathperyear
# Out:
#      Country_cod                     Country  Year  Deaths_Under_5  \
# 0            AFG                 Afghanistan  1990               0
# 1            ALB                     Albania  1990               0
# 2            DZA                     Algeria  1990               0
# 3            ASM              American Samoa  1990               0
# 4            NaN        Andean Latin America  1990               0
# ...          ...                         ...   ...             ...
# 6463         NaN  Western Sub-Saharan Africa  2017               0
# 6464    OWID_WRL                       World  2017               0
# 6465         YEM                       Yemen  2017               0
# 6466         ZMB                      Zambia  2017               0
# 6467         ZWE                    Zimbabwe  2017               0
#
#       Deaths_5-14_years  Deaths_15-49_years  Deaths_50-69_years  \
# 0                     1                 198                 159
# 1                     1                 107                 193
# 2                     3                 274                 161
# 3                     0                   2                   0
# 4                    26                6247                4865
# ...                 ...                 ...                 ...
# 6463                158               37109               43935
# 6464               3648              786663             1299483
# 6465                  2                 115                  31
# 6466                  7                2580                1976
# 6467                  9                3845                2676
#
#       Deaths_70+_years  Total_deaths  global_deaths_per_year
# 0                    1           359                 8893231
# 1                  153           454                 8893231
# 2                    5           443                 8893231
# 3                    0             2                 8893231
# 4                 1867         13005                 8893231
# ...                ...           ...                     ...
# 6463             17590         98792                13578923
# 6464            753060       2842854                13578923
# 6465                44           192                13578923
# 6466               724          5287                13578923
# 6467               698          7228                13578923
#
# [6468 rows x 10 columns]

# %% [markdown]
# Fullfill NaNs in column "Country_cod"

# %%
paises = alcoholdeath[['Country', 'Country_cod']].dropna()
paises = paises.groupby('Country').first()
alcoholdeath = pd.merge(alcoholdeath, paises, on = ['Country', 'Country_cod'])
alcoholdeath
# Out:
#      Country_cod      Country  Year  Deaths_Under_5  Deaths_5-14_years  \
# 0            AFG  Afghanistan  1990               0                  1
# 1            AFG  Afghanistan  1991               0                  1
# 2            AFG  Afghanistan  1992               0                  1
# 3            AFG  Afghanistan  1993               0                  1
# 4            AFG  Afghanistan  1994               0                  1
# ...          ...          ...   ...             ...                ...
# 5483         ZWE     Zimbabwe  2013               0                  8
# 5484         ZWE     Zimbabwe  2014               0                  8
# 5485         ZWE     Zimbabwe  2015               0                  8
# 5486         ZWE     Zimbabwe  2016               0                  8
# 5487         ZWE     Zimbabwe  2017               0                  9
#
#       Deaths_15-49_years  Deaths_50-69_years  Deaths_70+_years  Total_deaths
# 0                    198                 159                 1           359
# 1                    195                 134                10           340
# 2                    203                 107                18           329
# 3                    218                  84                25           328
# 4                    218                  63                31           313
# ...                  ...                 ...               ...           ...
# 5483                3978                2698               694          7378
# 5484                3870                2644               680          7202
# 5485                3852                2635               679          7174
# 5486                3839                2643               685          7175
# 5487                3845                2676               698          7228
#
# [5488 rows x 9 columns]

# %% [markdown]
# ## DataSet Rock history
# ### Review and read datset

# %%
file = open('C:/Users/forqu/OneDrive/Documentos/IronHack/Github/Projetos/History of Rock(1950-2020)/Data/history-of-rock-spotify.csv', 'rb')
file_lines = file.readlines(10000)
for i in range(5):
    print(file_lines[i].decode('latin-1'))
file.close()
rockhistory=pd.read_csv('C:/Users/forqu/OneDrive/Documentos/IronHack/Github/Projetos/History of Rock(1950-2020)/Data/history-of-rock-spotify.csv', sep = ',', decimal = '.', encoding = 'latin-1')
# Out:
# index,name,artist,release_date,length,popularity,danceability,acousticness,danceability,energy,instrumentalness,key,liveness,loudness,speechiness,tempo,time_signature,valence
#
# 0,Smells Like Teen Spirit,Nirvana,1991,5.032,74,0.502,2.55E-05,0.502,0.912,0.000173,1,0.106,-4.556,0.0564,116.761,4,0.72
#
# 1,Stairway to Heaven - Remaster,Led Zeppelin,1971,8.047166667,78,0.338,0.58,0.338,0.34,0.0032,9,0.116,-12.049,0.0339,82.433,4,0.197
#
# 2,Bohemian Rhapsody - Remastered 2011,Queen,1975,5.905333333,74,0.392,0.288,0.392,0.402,0,0,0.243,-9.961,0.0536,143.883,4,0.228
#
# 3,Imagine - Remastered 2010,John Lennon,1971,3.1311,77,0.547,0.907,0.547,0.257,0.183,0,0.0935,-12.358,0.0252,75.752,4,0.169

# %% [markdown]
# ### Clean DataSet Rock history

# %%
rockhistory= rockhistory.rename(columns={"release_date":"Year"})
rocksongs = rockhistory[['name','artist','Year']]
rocksongs['release'] = 1
rocksongs
# Out:
# <ipython-input-10-16667bb7554c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rocksongs['release'] = 1
#                                               name  \
# 0                          Smells Like Teen Spirit
# 1                    Stairway to Heaven - Remaster
# 2              Bohemian Rhapsody - Remastered 2011
# 3                        Imagine - Remastered 2010
# 4     (I Can't Get No) Satisfaction - Mono Version
# ...                                            ...
# 5479                              I'm In Your Mind
# 5480                                    Cellophane
# 5481                                     Hot Water
# 5482           Vitamin C - 2004 Remastered Version
# 5483                                             ~
#
#                                 artist  Year  popularity  energy  liveness  \
# 0                              Nirvana  1991          74   0.912    0.1060
# 1                         Led Zeppelin  1971          78   0.340    0.1160
# 2                                Queen  1975          74   0.402    0.2430
# 3                          John Lennon  1971          77   0.257    0.0935
# 4                   The Rolling Stones  1965          77   0.863    0.1280
# ...                                ...   ...         ...     ...       ...
# 5479  King Gizzard & The Lizard Wizard  2014          47   0.776    0.5970
# 5480  King Gizzard & The Lizard Wizard  2014          44   0.887    0.1200
# 5481  King Gizzard & The Lizard Wizard  2014          40   0.609    0.1160
# 5482                               CAN  1972          52   0.644    0.1620
# 5483                    TouchÃ© AmorÃ©  2011           0   0.959    0.1540
#
#       release
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 5479        1
# 5480        1
# 5481        1
# 5482        1
# 5483        1
#
# [5484 rows x 7 columns]

# %%
rocksongsperyear = rocksongs.groupby(['Year']).agg(
    toatla_release_per_year = pd.NamedAgg('release', 'sum'))
rockreleaseyear = rocksongs.merge(rocksongsperyear, on=['Year'])
rockreleaseyear
# Out:
#                          name                 artist  Year  popularity  \
# 0     Smells Like Teen Spirit                Nirvana  1991          74
# 1               Enter Sandman              Metallica  1991          74
# 2                         One                     U2  1991          76
# 3            Under the Bridge  Red Hot Chili Peppers  1991          81
# 4                       Alive              Pearl Jam  1991          75
# ...                       ...                    ...   ...         ...
# 5479                   My Gun             The Rubens  2012          33
# 5480    Prayer Of The Refugee           Rise Against  2012           0
# 5481           Alligator Skin               Villainy  2012          35
# 5482                     "45"    The Gaslight Anthem  2012          50
# 5483           Lupine Dominus           Thee Oh Sees  2012          29
#
#       energy  liveness  release  release_per_year
# 0      0.912    0.1060        1               106
# 1      0.824    0.0590        1               106
# 2      0.534    0.1550        1               106
# 3      0.345    0.1410        1               106
# 4      0.875    0.4020        1               106
# ...      ...       ...      ...               ...
# 5479   0.881    0.0608        1                83
# 5480   0.977    0.2300        1                83
# 5481   0.916    0.0575        1                83
# 5482   0.970    0.2770        1                83
# 5483   0.841    0.1290        1                83
#
# [5484 rows x 8 columns]

# %%
rocksongsperartist = rockreleaseyear.groupby(['artist']).agg(
    total_release_per_artist = pd.NamedAgg('artist', 'count'))
rocktotalrelease = rockreleaseyear.merge(rocksongsperartist, on=['artist'])
rocktotalrelease
# Out:
#                               name       artist  Year  popularity  energy  \
# 0          Smells Like Teen Spirit      Nirvana  1991          74   0.912
# 1                  Come As You Are      Nirvana  1991          72   0.824
# 2     In Bloom - Nevermind Version      Nirvana  1991          65   0.876
# 3                          Lithium      Nirvana  1991          68   0.656
# 4                            Breed      Nirvana  1991          59   0.969
# ...                            ...          ...   ...         ...     ...
# 5479              Take It On Faith    Matt Mays  2012          39   0.862
# 5480       Forever Tuesday Morning  The Mockers  2012          33   0.745
# 5481          Love Bites (So Do I)    Halestorm  2012          51   0.963
# 5482                    Scarecrows  One Bad Son  2012          31   0.800
# 5483                        My Gun   The Rubens  2012          33   0.881
#
#       liveness  release  release_per_year  release_per_artist
# 0       0.1060        1               106                  19
# 1       0.0916        1               106                  19
# 2       0.2050        1               106                  19
# 3       0.0631        1               106                  19
# 4       0.1330        1               106                  19
# ...        ...      ...               ...                 ...
# 5479    0.0609        1                83                   1
# 5480    0.2020        1                83                   1
# 5481    0.2530        1                83                   1
# 5482    0.1130        1                83                   1
# 5483    0.0608        1                83                   1
#
# [5484 rows x 9 columns]

# %%
rockhistory['artist'].unique()
# Out:
# array(['Nirvana', 'Led Zeppelin', 'Queen', ..., 'The Grumpies',
#        'Coachwhips', 'TouchÃ© AmorÃ©'], dtype=object)

# %% [markdown]
# # 3 Merge DataSets

# %%
alcohol_consuption_deaths = pd.merge(alcoholconsuption,alcoholdeath, on = ['Country', 'Year']) 
brazil = alcohol_consuption_deaths[alcohol_consuption_deaths['Country']=='Brazil']

# %%
Rock_alcohol_deaths = alcohol_consuption_deaths.merge(rocktotalrelease, on= ['Year'])
Rock_alcohol_deaths
# Out:
#                         Region      Country  Year Alcohol_type  \
# 0        Eastern Mediterranean  Afghanistan  2017         Beer
# 1        Eastern Mediterranean  Afghanistan  2017         Beer
# 2        Eastern Mediterranean  Afghanistan  2017         Beer
# 3        Eastern Mediterranean  Afghanistan  2017         Beer
# 4        Eastern Mediterranean  Afghanistan  2017         Beer
# ...                        ...          ...   ...          ...
# 2259056                 Europe     Slovakia  1990         Beer
# 2259057                 Europe     Slovakia  1990         Beer
# 2259058                 Europe     Slovakia  1990         Beer
# 2259059                 Europe     Slovakia  1990         Beer
# 2259060                 Europe     Slovakia  1990         Beer
#
#          Alcohol_consuption_lts Country_cod  Deaths_Under_5  \
# 0                           0.0         AFG               0
# 1                           0.0         AFG               0
# 2                           0.0         AFG               0
# 3                           0.0         AFG               0
# 4                           0.0         AFG               0
# ...                         ...         ...             ...
# 2259056                     6.4         SVK               0
# 2259057                     6.4         SVK               0
# 2259058                     6.4         SVK               0
# 2259059                     6.4         SVK               0
# 2259060                     6.4         SVK               0
#
#          Deaths_5-14_years  Deaths_15-49_years  Deaths_50-69_years  \
# 0                        3                 519                 128
# 1                        3                 519                 128
# 2                        3                 519                 128
# 3                        3                 519                 128
# 4                        3                 519                 128
# ...                    ...                 ...                 ...
# 2259056                  7                1189                2655
# 2259057                  7                1189                2655
# 2259058                  7                1189                2655
# 2259059                  7                1189                2655
# 2259060                  7                1189                2655
#
#          Deaths_70+_years  Total_deaths  \
# 0                      18           668
# 1                      18           668
# 2                      18           668
# 3                      18           668
# 4                      18           668
# ...                   ...           ...
# 2259056               585          4436
# 2259057               585          4436
# 2259058               585          4436
# 2259059               585          4436
# 2259060               585          4436
#
#                                                     name              artist  \
# 0        Always Crashing in the Same Car - 2017 Remaster         David Bowie
# 1                                          Black Sabbath       Black Sabbath
# 2                                             Drift Away     Various Artists
# 3                                 Baby, Let's Play House       Elvis Presley
# 4                                               Thriller     Michael Jackson
# ...                                                  ...                 ...
# 2259056                                             Joey     Concrete Blonde
# 2259057                                   Love Walked In             Thunder
# 2259058                                      High Enough        Damn Yankees
# 2259059                                   Hey You - Live       The Quireboys
# 2259060                                 She Ain't Pretty  The Northern Pikes
#
#          popularity  energy  liveness  release  release_per_year  \
# 0                40   0.731    0.0799        1                45
# 1                30   0.449    0.3220        1                45
# 2                55   0.460    0.6480        1                45
# 3                49   0.650    0.1220        1                45
# 4                72   0.887    0.8470        1                45
# ...             ...     ...       ...      ...               ...
# 2259056          57   0.788    0.1730        1                73
# 2259057          49   0.841    0.1340        1                73
# 2259058          60   0.537    0.0922        1                73
# 2259059          29   0.793    0.1080        1                73
# 2259060          46   0.787    0.1390        1                73
#
#          release_per_artist
# 0                        25
# 1                        20
# 2                       116
# 3                        33
# 4                         6
# ...                     ...
# 2259056                   1
# 2259057                   2
# 2259058                   1
# 2259059                   1
# 2259060                   1
#
# [2259061 rows x 20 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b155ad64dafb> in <module>
# ----> 1 Rock_alcohol_deaths.sort_values('artist', ascending=True).plot( x='artist',y=['release_per_year','release_per_artist'], kind ='bar', title='Rock songs Release and Alcohol consuption per Year')
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1473             else:
#    1474                 w = self.bar_width / K
# -> 1475                 rect = self._plot(
#    1476                     ax,
#    1477                     self.ax_pos + (i + 0.5) * w,
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1404     @classmethod
#    1405     def _plot(cls, ax: "Axes", x, y, w, start=0, log=False, **kwds):
# -> 1406         return ax.bar(x, y, w, bottom=start, log=log, **kwds)
#    1407
#    1408     @property
#
# ~\anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2492             elif orientation == 'horizontal':
#    2493                 r.sticky_edges.x.append(l)
# -> 2494             self.add_patch(r)
#    2495             patches.append(r)
#    2496
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    2031         if p.get_clip_path() is None:
#    2032             p.set_clip_path(self.patch)
# -> 2033         self._update_patch_limits(p)
#    2034         self.patches.append(p)
#    2035         p._remove_method = self.patches.remove
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_base.py in _update_patch_limits(self, patch)
#    2051         vertices = patch.get_path().vertices
#    2052         if vertices.size > 0:
# -> 2053             xys = patch.get_patch_transform().transform(vertices)
#    2054             if patch.get_data_transform() != self.transData:
#    2055                 patch_to_data = (patch.get_data_transform() -
#
# ~\anaconda\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     790
#     791     def get_patch_transform(self):
# --> 792         self._update_patch_transform()
#     793         return self._rect_transform
#     794
#
# ~\anaconda\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     772         rot_trans = transforms.Affine2D()
#     773         rot_trans.rotate_deg_around(x0, y0, self.angle)
# --> 774         self._rect_transform = transforms.BboxTransformTo(bbox)
#     775         self._rect_transform += rot_trans
#     776
#
# ~\anaconda\lib\site-packages\matplotlib\transforms.py in __init__(self, boxout, **kwargs)
#    2519         Affine2DBase.__init__(self, **kwargs)
#    2520         self._boxout = boxout
# -> 2521         self.set_children(boxout)
#    2522         self._mtx = None
#    2523         self._inverted = None
#
# ~\anaconda\lib\site-packages\matplotlib\transforms.py in set_children(self, *children)
#     197             # alive; the callback deletes the dictionary entry. This is a
#     198             # performance improvement over using WeakValueDictionary.
# --> 199             ref = weakref.ref(
#     200                 self, lambda _, pop=child._parents.pop, k=id(self): pop(k))
#     201             child._parents[id(self)] = ref
#
# KeyboardInterrupt:
