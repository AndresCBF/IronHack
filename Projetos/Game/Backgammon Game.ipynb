# %% [markdown]
# ## Backgammon
#
# Set Game:
# 1- Two players
# 2- Board with 4 quadrants with 6 lines in each
# 3- 30 round checkers, 15 white ones for one player, and 15 black ones for the opponent
# 4- Two 6 sided cubic dice with numbers 1-6 on it
#
# The initial position of the checkers for each player is on lines 1 with 2 pieces, and line 12 with 3 pieces, one one side, and lines 3 and 7, with 2 pieces, and lines 6 and 8 with 3 pieces, on the other side. The pieces move in the opposite direction of the opponent’s pieces around the board to the opposite 4th, home quadrant.
#
# ![image.png](attachment:image.png)
#
# To determine who which player goes first, each player throws one dice and whoever scores higher goes first. This throw does not count for the first move.

# %% [markdown]
# ## Rules
# 1- To determine who which player goes first, each player throws one dice and whoever scores higher goes first. This throw does not count for the first move.
# 2- To start moving, both dice are thrown together and the value on each dice is the number of lines each checker can move starting from line 1. There is no specific order in which the checkers have to move around the board. The player can move any of the checkers at any time.
# 3- There is no limit to how many checkers of a player can be present on a single line.
# A checker can be moved only to an open line. If a line is occupied by 2 or more checkers of a player, the opponent is not allowed to land on it.
# 4- The numbers on the two dice constitute separate moves. For example, if a player rolled 2 on one dice and 6 on the other dice, they may move one checker two spaces, and another checker 6 spaces. Or they can move the same checker 2 spaces onto an open line, and then move that same checker another 6 spaces onto an open line. The intermediate stop of the checker must not be occupied by two or more of the opponent’s checkers.
# 5- Bozorgmehr’s rules do not discuss scoring doubles (same number on both dice), and therefore in this rule set there is no special double move.
# 6- Moves are mandatory. If it is possible to make a move from both dice then the player must make both moves. If only one move is possible and the other is not then the player must make that one move. If neither moves are possible, then the player skips their turn.
# 7- If a single checker is present on a line, then it can be hit by an opponent’s checker and removed off the board onto the center bar, back to the beginning of the game. If there are two or more checkers present on a line then they are safe and the opponent cannot land on that line.
# 8- If the player has checkers sitting on the bar they must move them back into the game first, before moving any other pieces.
# 9- The checker on the bar lands onto the line equal to the number of one of the dice rolls, as long as that line is unoccupied.
# 10- The player may not move any other pieces, until all of the checkers on the bar have been reentered back into the game. 11- The player must make a move on the counts of both dice. So if one dice was used to move a checker from the bar, then the second dice must be used for another checker on the board, or the same checker to move further down the line.
# 12- The checkers can move off the board only after all 15 of them have arrived in the home quadrant first.
# 12- Checkers can be hit onto the bar even inside the home quadrant.

# %%
install keyboard
# Out:
#   File "<ipython-input-78-9afcfafb256b>", line 1
#     install keyboard
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np 
import random
import re

# %%
def jogador():
    """
    Solicita usaurio entrar nome do jogador, verifica que nõ aingrese numero so carateres alfanumericos
    """
    nome = input('Nome do Jogador: ')
    if len(nome)<3:
        print(f' Favor ingresar um nome, nome debe conter almenos 3 carater')
        return jogador()  
    elif nome.isspace():
        print(f' Favor ingresar um nome, nome debe conter almenos 3 carater')
        return jogador()         
    elif nome.isnumeric() :
        print(f' Favor ingresar um nome, nome não pode conter carateres numericos')
        return jogador()
    elif nome.isalpha() :
        return x
    else :
        print(f' Favor ingresar um nome, nome debe conter almenos 3 carater, nome não pode conter carateres numericos')
        return jogador()

# %%
class Dado():
    
    def __init__(self, dado=None):
        self.dado = dado
        
    def lancar():

        d = input('Você gostaria de lançar o dado [s/n]? ')
        if d == 's' or d == 'S' or d == 'sim' or d == 'Sim' or d =='SIM':
            dado = random.randint(1,6)
            return dado
        elif d == 'n' or d == 'N' or d == 'não' or d == 'Não' or d =='NÂO' :
            print ('Para continuar e necesario lançar o dado')
            return Dado.lancar()
        else:
            print('Para lançar o dado debe digitar sim [s]')
            return Dado.lancar()

# %%
class Tabuleiro():
        
    def __init__(self, tabuleiro = np.arange(24)) :
        self.tabuleiro = tabuleiro
    
    def iniciar(self, tabuleiro = np.zeros(24)):
        self.tabuleiro = tabuleiro 
        tabuleiro[0]=2
        tabuleiro[2]=-2
        tabuleiro[5]=-3
        tabuleiro[6]=-2
        tabuleiro[7]=-3
        tabuleiro[11]=3
        tabuleiro[12]=-3
        tabuleiro[16]=3
        tabuleiro[17]=2
        tabuleiro[18]=3
        tabuleiro[21]=2
        tabuleiro[23]=-2
        return tabuleiro 
    
    def mover(self,jogador):
        self.jogador=jogador
        posmov = []
        
        if jogador == jogador1 :
            
            for i in range (0,tabuleiro.size) :
                if tabuleiro[i] > 0:
                        posmov = posmov.add(i)
                        print(f'{jogador} pode movimentar as peças nas posições {posmov} do tabuleiro')
                        mov = int(input('a peça de que posição deseja movimentar?: '))
                        if mov is not posmov :
                            print(f'{jogador} favor escolher uma das seguentes posições {posmov} do tabuleiro')
                            return Tabuleiro.mover()
                        else :
                            return mov      
                        
        if jogador == jogador2 :
            
            for i in range (0,tabuleiro.size) :
                if tabuleiro[i] < 0 :
                        posmov = posmov.add(i)
                        print(f'{jogador} pode movimentar as peças nas posições {posmov} do tabuleiro')
                        mov = int(input('a peça de que posição deseja movimentar?: '))
                        if mov is not posmov :
                            print(f'{jogador} favor escolher uma das seguentes posições {posmov} do tabuleiro')
                            return Tabuleiro.mover()
                        else :
                            return mov

# %%
class Jogo():

    def __init__(self,jogador1,jogador2):
        self.jogador1 = jogador1
        self.jogador2 = jogador2

    def iniciar():
        
        print(f'{jogador1}: ')
        dadoj1 = Dado.lancar() 
    
        print(f'{jogador2}: ')
        dadoj2 = Dado.lancar()
        
        if dadoj1 > dadoj2 :
            print(f'{jogador1} inicia o jogo')
            jogador = jogador1
            return jogador
        elif dadoj2 > dadoj1 :
            print(f'{jogador2} inicia o jogo')
            jogador = jogador2
            return jogador
        else:
            print('Empate laçar dados novamante')
            return Jogo.iniciar()
    
    def mover(self,tabuleiro,jogador,dado1=None,dado2=None,J1=0,J2=0):
        
        self.tabuleiro = tabuleiro
        self.jogador = jogador
        self.dado1 = dado1
        self.dado2 = dado2
        self.J1 = J1
        self.J2 = J2

        print(tabuleiro)
            
            dado1 = Dado.lancar()
            dado2 = Dado.lancar()
            
            print(f'{jogador} lançou um {dado1} no primeiro dado, e um {dado2} no segundo dado')
            mov = Tabuleiro.mover(jogador)
        if J1 == 0 :
            if mov+dado1 > tabuleiro.size() :
            print(f'Não é possivel mover a peça da posição {mov}, valor do primer dado {dado1}')
                        
                    else :
                        if tabuleiro[i+dado1] = -1 :
                        tabuleiro[i] = tabuleiro[i] - 1
                        tabuleiro[i+dado1] = tabuleiro[i+dado1] + 2
                        J2 = +1
                        print(f'{jogador}, elimino uma peça do {jogador2}')
                        print(tabuleiro)
                            if J2 == 15 :
                                Jogo.fin()
                                print(f'{jogador2} não tem mais peças, {jogador} !!!!Ganou!!! ')   
                        elif tabuleiro[i+dado1] = 0 :
                            tabuleiro[i] = tabuleiro[i] - 1
                            tabuleiro[i+dado1] = tabuleiro[i+dado1] + 1
                            print(tabuleiro)
                    if mov+dado2 > tabuleiro.size() :
                        print(f'Não é possivel mover a peça da posição {mov}, valor do segundo dado {dado2}')
                        
                    else :
                        if tabuleiro[i+dado2] = -1 :
                        tabuleiro[i] = tabuleiro[i] - 1
                        tabuleiro[i+dado2] = tabuleiro[i+dado2] + 2
                        J2 = +1
                        print(f'{jogador}, elimino uma peça do {jogador2}')
                        print(tabuleiro)
                            if J2 == 15 :
                                Jogo.fin()
                                print(f'{jogador2} não tem mais peças, {jogador} !!!!Ganou!!! ')                                             
                        elif tabuleiro[i+dado2] = 0 :
                            tabuleiro[i] = tabuleiro[i] - 1
                            tabuleiro[i+dado2] = tabuleiro[i+dado2] + 1
                            print(tabuleiro)
                else J1 > 0 :
                    if tabuleiro[dado1] != 0 :
                        if tabuleiro[dado2] == 0:
                            tabuleiro[dado2] = 1
                            print(tabuleiro)
                        else :
                            print (f'{jogador} não tem movimentos, perde o turno)
                            jogador = jogador2
                            movimento = True 
                    else tabuleiro[dado1]== 0 :
                        tabuleiro[dado1] = 1
                        print(tabuleiro)
        
    def fin():
# Out:
# Nome do Jogador: Andres
# Nome do Jogador: Carlos
